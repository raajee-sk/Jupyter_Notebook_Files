# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from warnings import filterwarnings
filterwarnings("ignore")

# %%
df=pd.read_csv("Downloads/Football+Scholarship.csv")

# %%
df
# Out:
#       Academic_Score  Score_on_Plays_Made  Missed_Play_Score  \
# 0                7.0                0.270               0.36
# 1                6.3                0.300               0.34
# 2                8.1                0.280               0.40
# 3                7.2                0.230               0.32
# 4                7.2                0.230               0.32
# ...              ...                  ...                ...
# 6210             6.8                0.620               0.08
# 6211             6.2                0.600               0.08
# 6212             5.9                0.550               0.10
# 6213             6.3                0.510               0.13
# 6214             5.9                0.645               0.12
#
#      Injury_Propensity School_Type  School_Score  Overall_Score   Region  \
# 0                 High           A          0.45            8.8  Eastern
# 1                  Low           C          0.49            9.5  Eastern
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6215 entries, 0 to 6214
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Academic_Score       6215 non-null   float64
#  1   Score_on_Plays_Made  6215 non-null   float64
#  2   Missed_Play_Score    6215 non-null   float64
#  3   Injury_Propensity    6215 non-null   object
#  4   School_Type          6215 non-null   object
#  5   School_Score         6215 non-null   float64
#  6   Overall_Score        6215 non-null   float64
#  7   Region               6215 non-null   object
#  8   Scholarship          6215 non-null   object
# dtypes: float64(5), object(4)
# memory usage: 437.1+ KB

# %%
df.duplicated().sum()
# Out:
# 947

# %%
df.drop_duplicates()
# Out:
#       Academic_Score  Score_on_Plays_Made  Missed_Play_Score  \
# 0                7.0                0.270               0.36
# 1                6.3                0.300               0.34
# 2                8.1                0.280               0.40
# 3                7.2                0.230               0.32
# 6                6.2                0.320               0.16
# ...              ...                  ...                ...
# 6209             6.3                0.510               0.13
# 6210             6.8                0.620               0.08
# 6211             6.2                0.600               0.08
# 6212             5.9                0.550               0.10
# 6214             5.9                0.645               0.12
#
#      Injury_Propensity School_Type  School_Score  Overall_Score   Region  \
# 0                 High           A          0.45            8.8  Eastern
# 1                  Low           C          0.49            9.5  Eastern
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6215 entries, 0 to 6214
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Academic_Score       6215 non-null   float64
#  1   Score_on_Plays_Made  6215 non-null   float64
#  2   Missed_Play_Score    6215 non-null   float64
#  3   Injury_Propensity    6215 non-null   object
#  4   School_Type          6215 non-null   object
#  5   School_Score         6215 non-null   float64
#  6   Overall_Score        6215 non-null   float64
#  7   Region               6215 non-null   object
#  8   Scholarship          6215 non-null   object
# dtypes: float64(5), object(4)
# memory usage: 437.1+ KB

# %%
df.isnull().sum()
# Out:
# Academic_Score         0
# Score_on_Plays_Made    0
# Missed_Play_Score      0
# Injury_Propensity      0
# School_Type            0
# School_Score           0
# Overall_Score          0
# Region                 0
# Scholarship            0
# dtype: int64

# %%
df.describe()
# Out:
#        Academic_Score  Score_on_Plays_Made  Missed_Play_Score  School_Score  \
# count     6215.000000          6215.000000        6215.000000   6215.000000
# mean         7.219252             0.337338           0.319537      0.531448
# std          1.292237             0.160122           0.145153      0.147245
# min          3.800000             0.080000           0.000000      0.220000
# 25%          6.400000             0.230000           0.250000      0.430000
# 50%          7.000000             0.290000           0.310000      0.510000
# 75%          7.700000             0.400000           0.390000      0.600000
# max         15.900000             1.330000           1.660000      1.980000
#
#        Overall_Score
# count    6215.000000
# mean       10.456771
# std         1.172504
# min         8.000000
# 25%         9.500000
# 50%        10.200000
# 75%        11.300000
# max        14.900000

# %%
df.describe(include='object')
# Out:
#        Injury_Propensity School_Type   Region Scholarship
# count               6215        6215     6215        6215
# unique                 4           4        3           2
# top                  Low           C  Eastern     Partial
# freq                2650        3384     2835        4028

# %%
plt.figure(figsize=(20,20))
sns.boxplot(df)
# Out:
# <Axes: >

# %%
def remove_outlier(col):
    sorted(col)
    Q1,Q3=np.percentile(col,[25,75])
    IQR=Q3-Q1
    lower_range= Q1-(1.5 * IQR)
    upper_range= Q3+(1.5 * IQR)
    return lower_range, upper_range

# %%
for column in df.columns:
    if df[column].dtype != 'object': 
        lr,ur=remove_outlier(df[column])
        df[column]=np.where(df[column]>ur,ur,df[column])
        df[column]=np.where(df[column]<lr,lr,df[column])

# %%
plt.figure(figsize=(20,20))
sns.boxplot(df)
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['Academic_Score', 'Score_on_Plays_Made', 'Missed_Play_Score',
#        'Injury_Propensity', 'School_Type', 'School_Score', 'Overall_Score',
#        'Region', 'Scholarship'],
#       dtype='object')

# %%
print(df["Scholarship"].value_counts(normalize=True))
# Out:
# Partial    0.648109
# Full       0.351891
# Name: Scholarship, dtype: float64

# %%
sns.countplot(x=df["Scholarship"],data=df)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.corr()
# Out:
#                      Academic_Score  Score_on_Plays_Made  Missed_Play_Score  \
# Academic_Score             1.000000             0.238131           0.303391
# Score_on_Plays_Made        0.238131             1.000000          -0.381824
# Missed_Play_Score          0.303391            -0.381824           1.000000
# School_Score               0.288296             0.256837           0.045535
# Overall_Score             -0.099701            -0.040141          -0.010322
#
#                      School_Score  Overall_Score
# Academic_Score           0.288296      -0.099701
# Score_on_Plays_Made      0.256837      -0.040141
# Missed_Play_Score        0.045535      -0.010322
# School_Score             1.000000       0.013321
# Overall_Score            0.013321       1.000000

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(df,hue='Scholarship',diag_kind='kde')

# %%
df.columns
# Out:
# Index(['Academic_Score', 'Score_on_Plays_Made', 'Missed_Play_Score',
#        'Injury_Propensity', 'School_Type', 'School_Score', 'Overall_Score',
#        'Region', 'Scholarship'],
#       dtype='object')

# %%
df["Injury_Propensity"].value_counts()
# Out:
# Low         2650
# Normal      1319
# High        1181
# Moderate    1065
# Name: Injury_Propensity, dtype: int64

# %%
df["Injury_Propensity"]=df['Injury_Propensity'].replace({"Low":1,"Normal":2,"High":4,"Moderate":3})

# %%
df
# Out:
#       Academic_Score  Score_on_Plays_Made  Missed_Play_Score  \
# 0                7.0                0.270               0.36
# 1                6.3                0.300               0.34
# 2                8.1                0.280               0.40
# 3                7.2                0.230               0.32
# 4                7.2                0.230               0.32
# ...              ...                  ...                ...
# 6210             6.8                0.620               0.08
# 6211             6.2                0.600               0.08
# 6212             5.9                0.550               0.10
# 6213             6.3                0.510               0.13
# 6214             5.9                0.645               0.12
#
#       Injury_Propensity School_Type  School_Score  Overall_Score   Region  \
# 0                     4           A          0.45            8.8  Eastern
# 1                     1           C          0.49            9.5  Eastern
# ...

# %%
df["Scholarship"]=df["Scholarship"].replace({"Full":1,"Partial":0})

# %%
df
# Out:
#       Academic_Score  Score_on_Plays_Made  Missed_Play_Score  \
# 0                7.0                0.270               0.36
# 1                6.3                0.300               0.34
# 2                8.1                0.280               0.40
# 3                7.2                0.230               0.32
# 4                7.2                0.230               0.32
# ...              ...                  ...                ...
# 6210             6.8                0.620               0.08
# 6211             6.2                0.600               0.08
# 6212             5.9                0.550               0.10
# 6213             6.3                0.510               0.13
# 6214             5.9                0.645               0.12
#
#       Injury_Propensity School_Type  School_Score  Overall_Score   Region  \
# 0                     4           A          0.45            8.8  Eastern
# 1                     1           C          0.49            9.5  Eastern
# ...

# %%
df["Injury_Propensity"]=df["Injury_Propensity"].astype('int64')
df["Scholarship"]=df["Scholarship"].astype('int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6215 entries, 0 to 6214
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Academic_Score       6215 non-null   float64
#  1   Score_on_Plays_Made  6215 non-null   float64
#  2   Missed_Play_Score    6215 non-null   float64
#  3   Injury_Propensity    6215 non-null   int64
#  4   School_Type          6215 non-null   object
#  5   School_Score         6215 non-null   float64
#  6   Overall_Score        6215 non-null   float64
#  7   Region               6215 non-null   object
#  8   Scholarship          6215 non-null   int64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 437.1+ KB

# %%
df_dummy=pd.get_dummies(df,drop_first=True)

# %%
df_dummy
# Out:
#       Academic_Score  Score_on_Plays_Made  Missed_Play_Score  \
# 0                7.0                0.270               0.36
# 1                6.3                0.300               0.34
# 2                8.1                0.280               0.40
# 3                7.2                0.230               0.32
# 4                7.2                0.230               0.32
# ...              ...                  ...                ...
# 6210             6.8                0.620               0.08
# 6211             6.2                0.600               0.08
# 6212             5.9                0.550               0.10
# 6213             6.3                0.510               0.13
# 6214             5.9                0.645               0.12
#
#       Injury_Propensity  School_Score  Overall_Score  Scholarship  \
# 0                     4          0.45            8.8            0
# 1                     1          0.49            9.5            0
# ...

# %%
df_dummy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6215 entries, 0 to 6214
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Academic_Score       6215 non-null   float64
#  1   Score_on_Plays_Made  6215 non-null   float64
#  2   Missed_Play_Score    6215 non-null   float64
#  3   Injury_Propensity    6215 non-null   int64
#  4   School_Score         6215 non-null   float64
#  5   Overall_Score        6215 non-null   float64
#  6   Scholarship          6215 non-null   int64
#  7   School_Type_B        6215 non-null   uint8
#  8   School_Type_C        6215 non-null   uint8
#  9   School_Type_D        6215 non-null   uint8
#  10  Region_Southern      6215 non-null   uint8
#  11  Region_Western       6215 non-null   uint8
# dtypes: float64(5), int64(2), uint8(5)
# memory usage: 370.4 KB

# %% [markdown]
# # Use Full Data to develop a logistic regression model to identify significant predictors. Apply variable selection method as required. Show all intermediate models leading to the final model. Justify your choice of the final model. Which are the significant predictors?

# %% [markdown]
# # Compare values of model selection criteria for proposed models. Compare as many criteria as you feel are suitable.

# %%
import statsmodels.formula.api as sm

# %%
df_dummy.columns
# Out:
# Index(['Academic_Score', 'Score_on_Plays_Made', 'Missed_Play_Score',
#        'Injury_Propensity', 'School_Score', 'Overall_Score', 'Scholarship',
#        'School_Type_B', 'School_Type_C', 'School_Type_D', 'Region_Southern',
#        'Region_Western'],
#       dtype='object')

# %%
formula1='Scholarship~Academic_Score+Score_on_Plays_Made+Missed_Play_Score+Injury_Propensity+School_Score+Overall_Score+School_Type_B+School_Type_C+School_Type_D+Region_Southern+Region_Western'

# %%
logistic1=sm.logit(formula=formula1,data=df_dummy).fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.414033
#          Iterations 6

# %%
logistic1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:            Scholarship   No. Observations:                 6215
# Model:                          Logit   Df Residuals:                     6203
# Method:                           MLE   Df Model:                           11
# Date:                Tue, 31 Oct 2023   Pseudo R-squ.:                  0.3617
# Time:                        18:30:34   Log-Likelihood:                -2573.2
# converged:                       True   LL-Null:                       -4031.1
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ...
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept              -7.0628      0.582    -12.128      0.000      -8.204      -5.921
# ...

# %% [markdown]
# # Check for multicollinearity in the predictor variables using Variance Inflation Factor (VIF).

# %%
def vif_cal(input_data):
    x_vars=input_data
    xvar_names=input_data.columns
    for i in range(0,xvar_names.shape[0]):
        y=x_vars[xvar_names[i]] 
        x=x_vars[xvar_names.drop(xvar_names[i])]
        rsq=sm.ols(formula="y~x", data=x_vars).fit().rsquared  
        vif=round(1/(1-rsq),2)
        print (xvar_names[i], " VIF = " , vif)

# %%
vif_cal(input_data=df_dummy.drop('Scholarship',axis=1))
# Out:
# Academic_Score  VIF =  1.71
# Score_on_Plays_Made  VIF =  1.6
# Missed_Play_Score  VIF =  1.52
# Injury_Propensity  VIF =  1.83
# School_Score  VIF =  1.29
# Overall_Score  VIF =  2.03
# School_Type_B  VIF =  12.63
# School_Type_C  VIF =  11.37
# School_Type_D  VIF =  6.09
# Region_Southern  VIF =  1.23
# Region_Western  VIF =  1.25

# %% [markdown]
# # Model2

# %% [markdown]
# # Dropping the variable 'School_Type_B' since the multicollinearity is higher

# %%
formula2='Scholarship~Academic_Score+Score_on_Plays_Made+Missed_Play_Score+Injury_Propensity+School_Score+Overall_Score+School_Type_C+School_Type_D+Region_Southern+Region_Western'

# %%
logistic2=sm.logit(formula=formula2,data=df_dummy).fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.418110
#          Iterations 6

# %%
logistic1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:            Scholarship   No. Observations:                 6215
# Model:                          Logit   Df Residuals:                     6203
# Method:                           MLE   Df Model:                           11
# Date:                Tue, 31 Oct 2023   Pseudo R-squ.:                  0.3617
# Time:                        18:48:34   Log-Likelihood:                -2573.2
# converged:                       True   LL-Null:                       -4031.1
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ...
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept              -7.0628      0.582    -12.128      0.000      -8.204      -5.921
# ...

# %%
vif_cal(input_data=df_dummy.drop(['Scholarship','School_Type_B'],axis=1))
# Out:
# Academic_Score  VIF =  1.51
# Score_on_Plays_Made  VIF =  1.56
# Missed_Play_Score  VIF =  1.52
# Injury_Propensity  VIF =  1.54
# School_Score  VIF =  1.22
# Overall_Score  VIF =  1.67
# School_Type_C  VIF =  2.07
# School_Type_D  VIF =  2.65
# Region_Southern  VIF =  1.23
# Region_Western  VIF =  1.25

# %% [markdown]
# # Model3

# %% [markdown]
# # Dropping the variable 'School_Type_D' since the multicollinearity is higher

# %%
formula3='Scholarship~Academic_Score+Score_on_Plays_Made+Missed_Play_Score+Injury_Propensity+School_Score+Overall_Score+School_Type_C+Region_Southern+Region_Western'

# %%
logistic3=sm.logit(formula=formula3,data=df_dummy).fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.426660
#          Iterations 6

# %%
logistic3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:            Scholarship   No. Observations:                 6215
# Model:                          Logit   Df Residuals:                     6205
# Method:                           MLE   Df Model:                            9
# Date:                Tue, 31 Oct 2023   Pseudo R-squ.:                  0.3422
# Time:                        18:54:44   Log-Likelihood:                -2651.7
# converged:                       True   LL-Null:                       -4031.1
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ...
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept              -7.6789      0.507    -15.133      0.000      -8.673      -6.684
# ...

# %%
vif_cal(input_data=df_dummy.drop(['Scholarship','School_Type_B','School_Type_D'],axis=1))
# Out:
# Academic_Score  VIF =  1.4
# Score_on_Plays_Made  VIF =  1.51
# Missed_Play_Score  VIF =  1.52
# Injury_Propensity  VIF =  1.28
# School_Score  VIF =  1.18
# Overall_Score  VIF =  1.29
# School_Type_C  VIF =  1.12
# Region_Southern  VIF =  1.23
# Region_Western  VIF =  1.24

# %% [markdown]
# # Model4

# %% [markdown]
# # Dropping the variable 'Region western' and Scholl_Type_C since the variable is insignificant

# %%
formula4='Scholarship~Academic_Score+Score_on_Plays_Made+Missed_Play_Score+Injury_Propensity+School_Score+Overall_Score+Region_Southern'

# %%
logistic4=sm.logit(formula=formula4,data=df_dummy).fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.427851
#          Iterations 6

# %%
logistic4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:            Scholarship   No. Observations:                 6215
# Model:                          Logit   Df Residuals:                     6207
# Method:                           MLE   Df Model:                            7
# Date:                Tue, 31 Oct 2023   Pseudo R-squ.:                  0.3404
# Time:                        19:04:53   Log-Likelihood:                -2659.1
# converged:                       True   LL-Null:                       -4031.1
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ...
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept              -7.1249      0.484    -14.714      0.000      -8.074      -6.176
# ...

# %%
vif_cal(input_data=df_dummy.drop(['Scholarship','School_Type_B','School_Type_D','School_Type_C','Region_Western'],axis=1))
# Out:
# Academic_Score  VIF =  1.4
# Score_on_Plays_Made  VIF =  1.47
# Missed_Play_Score  VIF =  1.5
# Injury_Propensity  VIF =  1.26
# School_Score  VIF =  1.18
# Overall_Score  VIF =  1.22
# Region_Southern  VIF =  1.08
