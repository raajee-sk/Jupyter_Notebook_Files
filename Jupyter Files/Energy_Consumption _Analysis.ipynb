# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)

# %%
df1=pd.read_excel(r"C:\Users\SKAN\Downloads\normalized_bps_data_2011-2020_public_hospital.xlsx",1)
df1
# Out:
#               Sector              Sub Sector  \
# 0    Public Hospital  Acute/Chronic Hospital
# 1    Public Hospital  Acute/Chronic Hospital
# 2    Public Hospital  Acute/Chronic Hospital
# 3    Public Hospital        Chronic Hospital
# 4    Public Hospital  Acute/Chronic Hospital
# ..               ...                     ...
# 499  Public Hospital  Acute/Chronic Hospital
# 500  Public Hospital  Acute/Chronic Hospital
# 501  Public Hospital  Acute/Chronic Hospital
# 502  Public Hospital  Acute/Chronic Hospital
# 503  Public Hospital  Acute/Chronic Hospital
#
#                              Organization  \
# 0      Nipigon District Memorial Hospital
# 1      Nipigon District Memorial Hospital
# 2      Ottawa Queensway-Carleton Hospital
# 3     Toronto Runnymede Healthcare Centre
# 4               Renfrew Victoria Hospital
# ..                                    ...
# 499  Hamilton Health Sciences Corporation
# 500  Hamilton Health Sciences Corporation
# ...

# %%
df1["Year"]="2011"
df1.rename(columns={"2011 GHG Emissions (kg)":"GHG Emissions (kg)","2011 Energy Intensity (eWh/HDD/sq. ft)":"Energy Intensity (eWh/HDD/sq. ft)","2011 Energy Intensity (ekWh/ML)":"Energy Intensity (ekWh/ML)"},inplace=True)
df1
# Out:
#               Sector              Sub Sector  \
# 0    Public Hospital  Acute/Chronic Hospital
# 1    Public Hospital  Acute/Chronic Hospital
# 2    Public Hospital  Acute/Chronic Hospital
# 3    Public Hospital        Chronic Hospital
# 4    Public Hospital  Acute/Chronic Hospital
# ..               ...                     ...
# 499  Public Hospital  Acute/Chronic Hospital
# 500  Public Hospital  Acute/Chronic Hospital
# 501  Public Hospital  Acute/Chronic Hospital
# 502  Public Hospital  Acute/Chronic Hospital
# 503  Public Hospital  Acute/Chronic Hospital
#
#                              Organization  \
# 0      Nipigon District Memorial Hospital
# 1      Nipigon District Memorial Hospital
# 2      Ottawa Queensway-Carleton Hospital
# 3     Toronto Runnymede Healthcare Centre
# 4               Renfrew Victoria Hospital
# ..                                    ...
# 499  Hamilton Health Sciences Corporation
# 500  Hamilton Health Sciences Corporation
# ...

# %%
df2=pd.read_excel(r"C:\Users\SKAN\Downloads\normalized_bps_data_2011-2020_public_hospital.xlsx",2)
df2
# Out:
#               Sector              Sub Sector  \
# 0    Public Hospital  Acute/Chronic Hospital
# 1    Public Hospital  Acute/Chronic Hospital
# 2    Public Hospital  Acute/Chronic Hospital
# 3    Public Hospital  Acute/Chronic Hospital
# 4    Public Hospital  Acute/Chronic Hospital
# ..               ...                     ...
# 469  Public Hospital  Acute/Chronic Hospital
# 470  Public Hospital  Acute/Chronic Hospital
# 471  Public Hospital  Acute/Chronic Hospital
# 472  Public Hospital  Acute/Chronic Hospital
# 473  Public Hospital  Acute/Chronic Hospital
#
#                                Organization                      Operation  \
# 0                        Alexandra Hospital             Alexandra Hospital
# 1                        Alexandra Hospital             Alexandra Hospital
# 2    Alexandria Glengarry Memorial Hospital    Glengarry Memorial Hospital
# 3    Alexandria Glengarry Memorial Hospital    Glengarry Memorial Hospital
# ...

# %%
df2["Year"]="2012"
df2.rename(columns={"2012 GHG Emissions (kg)":"GHG Emissions (kg)","2012 Energy Intensity (eWh/HDD/sq. ft)":"Energy Intensity (eWh/HDD/sq. ft)","2012 Energy Intensity (ekWh/ML)":"Energy Intensity (ekWh/ML)"},inplace=True)
df2
# Out:
#               Sector              Sub Sector  \
# 0    Public Hospital  Acute/Chronic Hospital
# 1    Public Hospital  Acute/Chronic Hospital
# 2    Public Hospital  Acute/Chronic Hospital
# 3    Public Hospital  Acute/Chronic Hospital
# 4    Public Hospital  Acute/Chronic Hospital
# ..               ...                     ...
# 469  Public Hospital  Acute/Chronic Hospital
# 470  Public Hospital  Acute/Chronic Hospital
# 471  Public Hospital  Acute/Chronic Hospital
# 472  Public Hospital  Acute/Chronic Hospital
# 473  Public Hospital  Acute/Chronic Hospital
#
#                                Organization                      Operation  \
# 0                        Alexandra Hospital             Alexandra Hospital
# 1                        Alexandra Hospital             Alexandra Hospital
# 2    Alexandria Glengarry Memorial Hospital    Glengarry Memorial Hospital
# 3    Alexandria Glengarry Memorial Hospital    Glengarry Memorial Hospital
# ...

# %%
df3=pd.read_excel(r"C:\Users\SKAN\Downloads\normalized_bps_data_2011-2020_public_hospital.xlsx",3)
df3
# Out:
#               Sector              Sub Sector  \
# 0    Public Hospital  Acute/Chronic Hospital
# 1    Public Hospital  Acute/Chronic Hospital
# 2    Public Hospital  Acute/Chronic Hospital
# 3    Public Hospital  Acute/Chronic Hospital
# 4    Public Hospital  Acute/Chronic Hospital
# ..               ...                     ...
# 434  Public Hospital  Acute/Chronic Hospital
# 435  Public Hospital  Acute/Chronic Hospital
# 436  Public Hospital  Acute/Chronic Hospital
# 437  Public Hospital  Acute/Chronic Hospital
# 438  Public Hospital  Acute/Chronic Hospital
#
#                                Organization                      Operation  \
# 0                        Alexandra Hospital             Alexandra Hospital
# 1    Alexandria Glengarry Memorial Hospital    Glengarry Memorial Hospital
# 2    Alexandria Glengarry Memorial Hospital    Glengarry Memorial Hospital
# 3               Alliston Stevenson Memorial           Mental Health Centre
# ...

# %%
df3["Year"]="2013"
df3.rename(columns={"2013 GHG Emissions (kg)":"GHG Emissions (kg)","2013 Energy Intensity (eWh/HDD/sq. ft)":"Energy Intensity (eWh/HDD/sq. ft)","2013 Energy Intensity (ekWh/ML)":"Energy Intensity (ekWh/ML)"},inplace=True)
df3
# Out:
#               Sector              Sub Sector  \
# 0    Public Hospital  Acute/Chronic Hospital
# 1    Public Hospital  Acute/Chronic Hospital
# 2    Public Hospital  Acute/Chronic Hospital
# 3    Public Hospital  Acute/Chronic Hospital
# 4    Public Hospital  Acute/Chronic Hospital
# ..               ...                     ...
# 434  Public Hospital  Acute/Chronic Hospital
# 435  Public Hospital  Acute/Chronic Hospital
# 436  Public Hospital  Acute/Chronic Hospital
# 437  Public Hospital  Acute/Chronic Hospital
# 438  Public Hospital  Acute/Chronic Hospital
#
#                                Organization                      Operation  \
# 0                        Alexandra Hospital             Alexandra Hospital
# 1    Alexandria Glengarry Memorial Hospital    Glengarry Memorial Hospital
# 2    Alexandria Glengarry Memorial Hospital    Glengarry Memorial Hospital
# 3               Alliston Stevenson Memorial           Mental Health Centre
# ...

# %%
df4=pd.read_excel(r"C:\Users\SKAN\Downloads\normalized_bps_data_2011-2020_public_hospital.xlsx",4)
df4
# Out:
#               Sector              Sub Sector  \
# 0    Public Hospital  Acute/Chronic Hospital
# 1    Public Hospital  Acute/Chronic Hospital
# 2    Public Hospital  Acute/Chronic Hospital
# 3    Public Hospital  Acute/Chronic Hospital
# 4    Public Hospital  Acute/Chronic Hospital
# ..               ...                     ...
# 423  Public Hospital  Acute/Chronic Hospital
# 424  Public Hospital  Acute/Chronic Hospital
# 425  Public Hospital  Acute/Chronic Hospital
# 426  Public Hospital  Acute/Chronic Hospital
# 427  Public Hospital  Acute/Chronic Hospital
#
#                                Organization  \
# 0                        Alexandra Hospital
# 1    Alexandria Glengarry Memorial Hospital
# 2                  Almonte General Hospital
# 3                  Almonte General Hospital
# 4            Arnprior and District Memorial
# ..                                      ...
# 423           Wingham and District Hospital
# 424           Wingham and District Hospital
# ...

# %%
df4["Year"]="2014"
df4.rename(columns={"2014 GHG Emissions (kg)":"GHG Emissions (kg)","2014 Energy Intensity (eWh/HDD/sq. ft)":"Energy Intensity (eWh/HDD/sq. ft)","2014 Energy Intensity (ekWh/ML)":"Energy Intensity (ekWh/ML)"},inplace=True)
df4
# Out:
#               Sector              Sub Sector  \
# 0    Public Hospital  Acute/Chronic Hospital
# 1    Public Hospital  Acute/Chronic Hospital
# 2    Public Hospital  Acute/Chronic Hospital
# 3    Public Hospital  Acute/Chronic Hospital
# 4    Public Hospital  Acute/Chronic Hospital
# ..               ...                     ...
# 423  Public Hospital  Acute/Chronic Hospital
# 424  Public Hospital  Acute/Chronic Hospital
# 425  Public Hospital  Acute/Chronic Hospital
# 426  Public Hospital  Acute/Chronic Hospital
# 427  Public Hospital  Acute/Chronic Hospital
#
#                                Organization  \
# 0                        Alexandra Hospital
# 1    Alexandria Glengarry Memorial Hospital
# 2                  Almonte General Hospital
# 3                  Almonte General Hospital
# 4            Arnprior and District Memorial
# ..                                      ...
# 423           Wingham and District Hospital
# 424           Wingham and District Hospital
# ...

# %%
df5=pd.read_excel(r"C:\Users\SKAN\Downloads\normalized_bps_data_2011-2020_public_hospital.xlsx",5)
df5
# Out:
#               Sector              Sub Sector  \
# 0    Public Hospital  Acute/Chronic Hospital
# 1    Public Hospital  Acute/Chronic Hospital
# 2    Public Hospital  Acute/Chronic Hospital
# 3    Public Hospital  Acute/Chronic Hospital
# 4    Public Hospital  Acute/Chronic Hospital
# ..               ...                     ...
# 426  Public Hospital  Acute/Chronic Hospital
# 427  Public Hospital  Acute/Chronic Hospital
# 428  Public Hospital  Acute/Chronic Hospital
# 429  Public Hospital  Acute/Chronic Hospital
# 430  Public Hospital  Acute/Chronic Hospital
#
#                                Organization                      Operation  \
# 0                        Alexandra Hospital  Alexandra Hospital, Ingersoll
# 1    Alexandria Glengarry Memorial Hospital    Glengarry Memorial Hospital
# 2               Alliston Stevenson Memorial    Stevenson Memorial Hospital
# 3               Alliston Stevenson Memorial    Stevenson Memorial Hospital
# ...

# %%
df5["Year"]="2015"
df5.rename(columns={"2015 GHG Emissions (kg)":"GHG Emissions (kg)","2015 Energy Intensity (eWh/HDD/sq. ft)":"Energy Intensity (eWh/HDD/sq. ft)","2015 Energy Intensity (ekWh/ML)":"Energy Intensity (ekWh/ML)"},inplace=True)
df5
# Out:
#               Sector              Sub Sector  \
# 0    Public Hospital  Acute/Chronic Hospital
# 1    Public Hospital  Acute/Chronic Hospital
# 2    Public Hospital  Acute/Chronic Hospital
# 3    Public Hospital  Acute/Chronic Hospital
# 4    Public Hospital  Acute/Chronic Hospital
# ..               ...                     ...
# 426  Public Hospital  Acute/Chronic Hospital
# 427  Public Hospital  Acute/Chronic Hospital
# 428  Public Hospital  Acute/Chronic Hospital
# 429  Public Hospital  Acute/Chronic Hospital
# 430  Public Hospital  Acute/Chronic Hospital
#
#                                Organization                      Operation  \
# 0                        Alexandra Hospital  Alexandra Hospital, Ingersoll
# 1    Alexandria Glengarry Memorial Hospital    Glengarry Memorial Hospital
# 2               Alliston Stevenson Memorial    Stevenson Memorial Hospital
# 3               Alliston Stevenson Memorial    Stevenson Memorial Hospital
# ...

# %%
df6=pd.read_excel(r"C:\Users\SKAN\Downloads\normalized_bps_data_2011-2020_public_hospital.xlsx",6)
df6
# Out:
#               Sector              Sub Sector  \
# 0    Public Hospital  Acute/Chronic Hospital
# 1    Public Hospital  Acute/Chronic Hospital
# 2    Public Hospital  Acute/Chronic Hospital
# 3    Public Hospital  Acute/Chronic Hospital
# 4    Public Hospital  Acute/Chronic Hospital
# ..               ...                     ...
# 433  Public Hospital  Acute/Chronic Hospital
# 434  Public Hospital  Acute/Chronic Hospital
# 435  Public Hospital  Acute/Chronic Hospital
# 436  Public Hospital  Acute/Chronic Hospital
# 437  Public Hospital  Acute/Chronic Hospital
#
#                                Organization                      Operation  \
# 0                        Alexandra Hospital  Alexandra Hospital, Ingersoll
# 1    Alexandria Glengarry Memorial Hospital    Glengarry Memorial Hospital
# 2               Alliston Stevenson Memorial    Stevenson Memorial Hospital
# 3                  Almonte General Hospital       Almonte General Hospital
# ...

# %%
df6["Year"]="2016"
df6.rename(columns={"2016 GHG Emissions (kg)":"GHG Emissions (kg)","2016 Energy Intensity (eWh/HDD/sq. ft)":"Energy Intensity (eWh/HDD/sq. ft)","2016 Energy Intensity (ekWh/ML)":"Energy Intensity (ekWh/ML)"},inplace=True)
df6
# Out:
#               Sector              Sub Sector  \
# 0    Public Hospital  Acute/Chronic Hospital
# 1    Public Hospital  Acute/Chronic Hospital
# 2    Public Hospital  Acute/Chronic Hospital
# 3    Public Hospital  Acute/Chronic Hospital
# 4    Public Hospital  Acute/Chronic Hospital
# ..               ...                     ...
# 433  Public Hospital  Acute/Chronic Hospital
# 434  Public Hospital  Acute/Chronic Hospital
# 435  Public Hospital  Acute/Chronic Hospital
# 436  Public Hospital  Acute/Chronic Hospital
# 437  Public Hospital  Acute/Chronic Hospital
#
#                                Organization                      Operation  \
# 0                        Alexandra Hospital  Alexandra Hospital, Ingersoll
# 1    Alexandria Glengarry Memorial Hospital    Glengarry Memorial Hospital
# 2               Alliston Stevenson Memorial    Stevenson Memorial Hospital
# 3                  Almonte General Hospital       Almonte General Hospital
# ...

# %%
df7=pd.read_excel(r"C:\Users\SKAN\Downloads\normalized_bps_data_2011-2020_public_hospital.xlsx",7)
df7
# Out:
#               Sector              Sub Sector  \
# 0    Public Hospital  Acute/Chronic Hospital
# 1    Public Hospital  Acute/Chronic Hospital
# 2    Public Hospital  Acute/Chronic Hospital
# 3    Public Hospital  Acute/Chronic Hospital
# 4    Public Hospital  Acute/Chronic Hospital
# ..               ...                     ...
# 393  Public Hospital  Acute/Chronic Hospital
# 394  Public Hospital  Acute/Chronic Hospital
# 395  Public Hospital  Acute/Chronic Hospital
# 396  Public Hospital  Acute/Chronic Hospital
# 397  Public Hospital  Acute/Chronic Hospital
#
#                                Organization  \
# 0                        Alexandra Hospital
# 1    Alexandria Glengarry Memorial Hospital
# 2                  Almonte General Hospital
# 3                  Almonte General Hospital
# 4            Arnprior and District Memorial
# ..                                      ...
# 393           Wingham and District Hospital
# 394           Wingham and District Hospital
# ...

# %%
df7["Year"]="2017"
df7.rename(columns={"2017 GHG Emissions (kg)":"GHG Emissions (kg)","2017 Energy Intensity (eWh/HDD/sq. ft)":"Energy Intensity (eWh/HDD/sq. ft)","2017 Energy Intensity (ekWh/ML)":"Energy Intensity (ekWh/ML)"},inplace=True)
df7
# Out:
#               Sector              Sub Sector  \
# 0    Public Hospital  Acute/Chronic Hospital
# 1    Public Hospital  Acute/Chronic Hospital
# 2    Public Hospital  Acute/Chronic Hospital
# 3    Public Hospital  Acute/Chronic Hospital
# 4    Public Hospital  Acute/Chronic Hospital
# ..               ...                     ...
# 393  Public Hospital  Acute/Chronic Hospital
# 394  Public Hospital  Acute/Chronic Hospital
# 395  Public Hospital  Acute/Chronic Hospital
# 396  Public Hospital  Acute/Chronic Hospital
# 397  Public Hospital  Acute/Chronic Hospital
#
#                                Organization  \
# 0                        Alexandra Hospital
# 1    Alexandria Glengarry Memorial Hospital
# 2                  Almonte General Hospital
# 3                  Almonte General Hospital
# 4            Arnprior and District Memorial
# ..                                      ...
# 393           Wingham and District Hospital
# 394           Wingham and District Hospital
# ...

# %%
df8=pd.read_excel(r"C:\Users\SKAN\Downloads\normalized_bps_data_2011-2020_public_hospital.xlsx",8)
df8
# Out:
#               Sector              Sub Sector  \
# 0    Public Hospital  Acute/Chronic Hospital
# 1    Public Hospital  Acute/Chronic Hospital
# 2    Public Hospital  Acute/Chronic Hospital
# 3    Public Hospital  Acute/Chronic Hospital
# 4    Public Hospital  Acute/Chronic Hospital
# ..               ...                     ...
# 341  Public Hospital  Acute/Chronic Hospital
# 342  Public Hospital  Acute/Chronic Hospital
# 343  Public Hospital  Acute/Chronic Hospital
# 344  Public Hospital  Acute/Chronic Hospital
# 345  Public Hospital  Acute/Chronic Hospital
#
#                                   Organization  \
# 0                           Alexandra Hospital
# 1                     Almonte General Hospital
# 2                     Almonte General Hospital
# 3                    Atikokan General Hospital
# 4    Barry's Bay St. Frances Memorial Hospital
# ..                                         ...
# 341            Simcoe Norfolk General Hospital
# ...

# %%
df8["Year"]="2018"
df8.rename(columns={"2018 GHG Emissions (kg)":"GHG Emissions (kg)","2018 Energy Intensity (eWh/HDD/sq. ft)":"Energy Intensity (eWh/HDD/sq. ft)","2018 Energy Intensity (ekWh/ML)":"Energy Intensity (ekWh/ML)"},inplace=True)
df8
# Out:
#               Sector              Sub Sector  \
# 0    Public Hospital  Acute/Chronic Hospital
# 1    Public Hospital  Acute/Chronic Hospital
# 2    Public Hospital  Acute/Chronic Hospital
# 3    Public Hospital  Acute/Chronic Hospital
# 4    Public Hospital  Acute/Chronic Hospital
# ..               ...                     ...
# 341  Public Hospital  Acute/Chronic Hospital
# 342  Public Hospital  Acute/Chronic Hospital
# 343  Public Hospital  Acute/Chronic Hospital
# 344  Public Hospital  Acute/Chronic Hospital
# 345  Public Hospital  Acute/Chronic Hospital
#
#                                   Organization  \
# 0                           Alexandra Hospital
# 1                     Almonte General Hospital
# 2                     Almonte General Hospital
# 3                    Atikokan General Hospital
# 4    Barry's Bay St. Frances Memorial Hospital
# ..                                         ...
# 341            Simcoe Norfolk General Hospital
# ...

# %%
df9=pd.read_excel(r"C:\Users\SKAN\Downloads\normalized_bps_data_2011-2020_public_hospital.xlsx",9)
df9
# Out:
#               Sector              Sub Sector  \
# 0    Public Hospital  Acute/Chronic Hospital
# 1    Public Hospital  Acute/Chronic Hospital
# 2    Public Hospital  Acute/Chronic Hospital
# 3    Public Hospital  Acute/Chronic Hospital
# 4    Public Hospital  Acute/Chronic Hospital
# ..               ...                     ...
# 357  Public Hospital  Acute/Chronic Hospital
# 358  Public Hospital  Acute/Chronic Hospital
# 359  Public Hospital  Acute/Chronic Hospital
# 360  Public Hospital  Acute/Chronic Hospital
# 361  Public Hospital  Acute/Chronic Hospital
#
#                                Organization  \
# 0                        Alexandra Hospital
# 1    Alexandria Glengarry Memorial Hospital
# 2                  Almonte General Hospital
# 3                  Almonte General Hospital
# 4            Arnprior and District Memorial
# ..                                      ...
# 357           Wingham and District Hospital
# 358           Wingham and District Hospital
# ...

# %%
df9["Year"]="2019"
df9.rename(columns={"2019 GHG Emissions (kg)":"GHG Emissions (kg)","2019 Energy Intensity (eWh/HDD/sq. ft)":"Energy Intensity (eWh/HDD/sq. ft)","2019 Energy Intensity (ekWh/ML)":"Energy Intensity (ekWh/ML)"},inplace=True)
df9
# Out:
#               Sector              Sub Sector  \
# 0    Public Hospital  Acute/Chronic Hospital
# 1    Public Hospital  Acute/Chronic Hospital
# 2    Public Hospital  Acute/Chronic Hospital
# 3    Public Hospital  Acute/Chronic Hospital
# 4    Public Hospital  Acute/Chronic Hospital
# ..               ...                     ...
# 357  Public Hospital  Acute/Chronic Hospital
# 358  Public Hospital  Acute/Chronic Hospital
# 359  Public Hospital  Acute/Chronic Hospital
# 360  Public Hospital  Acute/Chronic Hospital
# 361  Public Hospital  Acute/Chronic Hospital
#
#                                Organization  \
# 0                        Alexandra Hospital
# 1    Alexandria Glengarry Memorial Hospital
# 2                  Almonte General Hospital
# 3                  Almonte General Hospital
# 4            Arnprior and District Memorial
# ..                                      ...
# 357           Wingham and District Hospital
# 358           Wingham and District Hospital
# ...

# %%
df10=pd.read_excel(r"C:\Users\SKAN\Downloads\normalized_bps_data_2011-2020_public_hospital.xlsx",10)
df10
# Out:
#               Sector               SubSector  \
# 0    Public Hospital  Acute/Chronic Hospital
# 1    Public Hospital  Acute/Chronic Hospital
# 2    Public Hospital  Acute/Chronic Hospital
# 3    Public Hospital  Acute/Chronic Hospital
# 4    Public Hospital          Acute Hospital
# ..               ...                     ...
# 349  Public Hospital  Acute/Chronic Hospital
# 350  Public Hospital  Acute/Chronic Hospital
# 351  Public Hospital  Acute/Chronic Hospital
# 352  Public Hospital  Acute/Chronic Hospital
# 353  Public Hospital  Acute/Chronic Hospital
#
#                                      Organization  \
# 0                              Alexandra Hospital
# 1                        Almonte General Hospital
# 2                        Almonte General Hospital
# 3                       Atikokan General Hospital
# 4    Barrie Royal Victoria Regional Health Centre
# ..                                            ...
# 349                 Wingham and District Hospital
# ...

# %%
df10["Year"]="2020"
df10.rename(columns={"SubSector":"Sub Sector"},inplace=True)
df10
# Out:
#               Sector              Sub Sector  \
# 0    Public Hospital  Acute/Chronic Hospital
# 1    Public Hospital  Acute/Chronic Hospital
# 2    Public Hospital  Acute/Chronic Hospital
# 3    Public Hospital  Acute/Chronic Hospital
# 4    Public Hospital          Acute Hospital
# ..               ...                     ...
# 349  Public Hospital  Acute/Chronic Hospital
# 350  Public Hospital  Acute/Chronic Hospital
# 351  Public Hospital  Acute/Chronic Hospital
# 352  Public Hospital  Acute/Chronic Hospital
# 353  Public Hospital  Acute/Chronic Hospital
#
#                                      Organization  \
# 0                              Alexandra Hospital
# 1                        Almonte General Hospital
# 2                        Almonte General Hospital
# 3                       Atikokan General Hospital
# 4    Barrie Royal Victoria Regional Health Centre
# ..                                            ...
# 349                 Wingham and District Hospital
# ...

# %%
df=pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10])
df
# Out:
#               Sector              Sub Sector  \
# 0    Public Hospital  Acute/Chronic Hospital
# 1    Public Hospital  Acute/Chronic Hospital
# 2    Public Hospital  Acute/Chronic Hospital
# 3    Public Hospital        Chronic Hospital
# 4    Public Hospital  Acute/Chronic Hospital
# ..               ...                     ...
# 349  Public Hospital  Acute/Chronic Hospital
# 350  Public Hospital  Acute/Chronic Hospital
# 351  Public Hospital  Acute/Chronic Hospital
# 352  Public Hospital  Acute/Chronic Hospital
# 353  Public Hospital  Acute/Chronic Hospital
#
#                             Organization                           Operation  \
# 0     Nipigon District Memorial Hospital  Nipigon District Memorial Hospital
# 1     Nipigon District Memorial Hospital              Nipigon Medical Clinic
# 2     Ottawa Queensway-Carleton Hospital         Queensway Carleton Hospital
# 3    Toronto Runnymede Healthcare Centre         Runnymede Healthcare Centre
# ...

# %%
df.shape
# Out:
# (4174, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4174 entries, 0 to 353
# Data columns (total 12 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Sector                             4174 non-null   object
#  1   Sub Sector                         4174 non-null   object
#  2   Organization                       4174 non-null   object
#  3   Operation                          4174 non-null   object
#  4   Operation Type                     4174 non-null   object
#  5   Address                            4174 non-null   object
#  6   City                               4174 non-null   object
#  7   Postal Code                        4174 non-null   object
#  8   GHG Emissions (kg)                 4174 non-null   float64
#  9   Energy Intensity (eWh/HDD/sq. ft)  4161 non-null   float64
#  10  Energy Intensity (ekWh/ML)         13 non-null     float64
# ...

# %%
df.isnull().sum()
# Out:
# Sector                                  0
# Sub Sector                              0
# Organization                            0
# Operation                               0
# Operation Type                          0
# Address                                 0
# City                                    0
# Postal Code                             0
# GHG Emissions (kg)                      0
# Energy Intensity (eWh/HDD/sq. ft)      13
# Energy Intensity (ekWh/ML)           4161
# Year                                    0
# dtype: int64

# %% [markdown]
# Energy Intensity (ekWh/ML) have more than 90% data are missing in dataframe.So drop this column from dataset

# %%
df.dropna(subset='Energy Intensity (eWh/HDD/sq. ft)',inplace=True)

# %%
df.drop(["Energy Intensity (ekWh/ML)"],axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# Sector                               0
# Sub Sector                           0
# Organization                         0
# Operation                            0
# Operation Type                       0
# Address                              0
# City                                 0
# Postal Code                          0
# GHG Emissions (kg)                   0
# Energy Intensity (eWh/HDD/sq. ft)    0
# Year                                 0
# dtype: int64

# %%
df.dtypes
# Out:
# Sector                                object
# Sub Sector                            object
# Organization                          object
# Operation                             object
# Operation Type                        object
# Address                               object
# City                                  object
# Postal Code                           object
# GHG Emissions (kg)                   float64
# Energy Intensity (eWh/HDD/sq. ft)    float64
# Year                                  object
# dtype: object

# %%
df["Year"]=df["Year"].astype(int)

# %%
df.dtypes
# Out:
# Sector                                object
# Sub Sector                            object
# Organization                          object
# Operation                             object
# Operation Type                        object
# Address                               object
# City                                  object
# Postal Code                           object
# GHG Emissions (kg)                   float64
# Energy Intensity (eWh/HDD/sq. ft)    float64
# Year                                   int32
# dtype: object

# %%
df
# Out:
#               Sector              Sub Sector  \
# 0    Public Hospital  Acute/Chronic Hospital
# 1    Public Hospital  Acute/Chronic Hospital
# 2    Public Hospital  Acute/Chronic Hospital
# 3    Public Hospital        Chronic Hospital
# 4    Public Hospital  Acute/Chronic Hospital
# ..               ...                     ...
# 349  Public Hospital  Acute/Chronic Hospital
# 350  Public Hospital  Acute/Chronic Hospital
# 351  Public Hospital  Acute/Chronic Hospital
# 352  Public Hospital  Acute/Chronic Hospital
# 353  Public Hospital  Acute/Chronic Hospital
#
#                             Organization                           Operation  \
# 0     Nipigon District Memorial Hospital  Nipigon District Memorial Hospital
# 1     Nipigon District Memorial Hospital              Nipigon Medical Clinic
# 2     Ottawa Queensway-Carleton Hospital         Queensway Carleton Hospital
# 3    Toronto Runnymede Healthcare Centre         Runnymede Healthcare Centre
# ...

# %%
df.to_csv(r"C:\Users\SKAN\Desktop\Raajee\Energy_Consumption.csv")
